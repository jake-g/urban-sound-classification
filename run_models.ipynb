# %%
# %time %run dump_features.py
# Out:
# Extracting mfccs
# parsing fold1...
# parsing fold2...
# parsing fold3...
# parsing fold4...
# parsing fold5...
# parsing fold6...
# parsing fold7...
# parsing fold8...
# parsing fold9...
# parsing fold10...
# dumping features_mfccs...
# dumping labels_mfccs...
# Extracting means
# parsing fold1...
# /usr/local/lib/python2.7/dist-packages/numpy/core/numeric.py:482: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python2.7/dist-packages/librosa/core/pitch.py:148: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
# /usr/local/lib/python2.7/dist-packages/librosa/util/utils.py:1459: RuntimeWarning: invalid value encountered in less
#   if np.any(X < 0) or np.any(X_ref < 0):
# ...

# %%
# %time %run cnn.py
# Out:
# loading.../home/jk/Desktop/urban_sound_data/features_specs.p
# loading.../home/jk/Desktop/urban_sound_data/labels_specs.p
# Train on 43722 samples, validate on 5118 samples
# Epoch 1/50
# 43722/43722 [==============================] - 7s - loss: 2.0836 - acc: 0.2602 - val_loss: 1.8054 - val_acc: 0.3509
# Epoch 2/50
# 43722/43722 [==============================] - 6s - loss: 1.8407 - acc: 0.3441 - val_loss: 1.5992 - val_acc: 0.4064
# Epoch 3/50
# 43722/43722 [==============================] - 6s - loss: 1.7415 - acc: 0.3753 - val_loss: 1.4319 - val_acc: 0.4867
# Epoch 4/50
# 43722/43722 [==============================] - 6s - loss: 1.6568 - acc: 0.4006 - val_loss: 1.5042 - val_acc: 0.4611
# Epoch 5/50
# 43722/43722 [==============================] - 6s - loss: 1.5913 - acc: 0.4216 - val_loss: 1.4081 - val_acc: 0.5617
# Epoch 6/50
# 43722/43722 [==============================] - 7s - loss: 1.5449 - acc: 0.4401 - val_loss: 1.4263 - val_acc: 0.5461
# Epoch 7/50
# ...

# %%
# %time %run ffn.py
# Out:
# loading.../home/jk/Desktop/urban_sound_data/features_means.p
# loading.../home/jk/Desktop/urban_sound_data/labels_means.p
# Train on 7079 samples, validate on 816 samples
# Epoch 1/50
# 7079/7079 [==============================] - 0s - loss: 6.7639 - acc: 0.2544 - val_loss: 1.9212 - val_acc: 0.4167
# Epoch 2/50
# 7079/7079 [==============================] - 0s - loss: 1.8921 - acc: 0.4316 - val_loss: 1.4883 - val_acc: 0.5245
# Epoch 3/50
# 7079/7079 [==============================] - 0s - loss: 1.5507 - acc: 0.5204 - val_loss: 1.4273 - val_acc: 0.5147
# Epoch 4/50
# 7079/7079 [==============================] - 0s - loss: 1.3395 - acc: 0.5820 - val_loss: 1.4186 - val_acc: 0.5294
# Epoch 5/50
# 7079/7079 [==============================] - 0s - loss: 1.1959 - acc: 0.6207 - val_loss: 1.4557 - val_acc: 0.5748
# Epoch 6/50
# 7079/7079 [==============================] - 0s - loss: 1.0602 - acc: 0.6644 - val_loss: 1.4262 - val_acc: 0.5858
# Epoch 7/50
# ...

# %%
# %time %run rnn.py
# Out:
# loading.../home/jk/Desktop/urban_sound_data/features_mfccs.p
# loading.../home/jk/Desktop/urban_sound_data/labels_mfccs.p
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/gradients.py:90: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/jk/Dropbox/projects/sound-classification/rnn.py in <module>()
#      64         offset = (itr * batch_size) % (train_y.shape[0] - batch_size)
#      65         batch_x = train_x[offset:(offset + batch_size), :, :]
# ---> 66         batch_y = train_y[offset:(offset + batch_size), :]
#      67         _, c = session.run([optimizer, loss_f], feed_dict={x: batch_x, y: batch_y})
#      68
#
# IndexError: too many indices for array
# ...

# %%
# load dataset
paths = u.load_paths('PATHS.yaml')  # get paths from file
train_x, val_x, test_x = u.load_data(paths['extracted_data'] + 'features_mfccs.p')
train_y, val_y, test_y = u.load_data(paths['extracted_data'] + 'labels_mfccs.p')
# Out:
# loading.../home/jk/Desktop/urban_sound_data/features_mfccs.p
# loading.../home/jk/Desktop/urban_sound_data/labels_mfccs.p
